# %% [markdown]
# <h1>Spam  Email Detector</h1>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
spam_df=pd.read_csv(r"C:/users/msomw/python onlyfans/stockprediction/spam.csv")

# %%
spam_df.groupby('Category').describe()
# Out:
#          Message                                                            \
#            count unique                                                top
# Category
# ham         4825   4516                             Sorry, I'll call later
# spam         747    641  Please call our customer service representativ...
#
#
#          freq
# Category
# ham        30
# spam        4

# %%
spam_df['spam']=spam_df['Category'].apply(lambda x:1 if x =='spam' else 0)

# %%
spam_df
# Out:
#        label                                               text
# 0          1  ounce feather bowl hummingbird opec moment ala...
# 1          1  wulvob get your medircations online qnb ikud v...
# 2          0   computer connection from cnn com wednesday es...
# 3          1  university degree obtain a prosperous future m...
# 4          0  thanks for all your answers guys i know i shou...
# ...      ...                                                ...
# 83443      0  hi given a date how do i get the last date of ...
# 83444      1  now you can order software on cd or download i...
# 83445      1  dear valued member canadianpharmacy provides a...
# 83446      0  subscribe change profile contact us long term ...
# 83447      1  get the most out of life ! viagra has helped m...
#
# [83448 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(spam_df.Message,spam_df.spam,test_size=0.25)

# %%
#x_train

# %%
cv=CountVectorizer()
x_vectorized=cv.fit_transform(spam_df['text'])

# %%
#x_train_count.toarray()

# %%
model=MultinomialNB()
model.fit(x_vectorized,spam_df['label'])
# Out:
# MultinomialNB()

# %%
'''email_ham=["hey wanna meet up for the game"]
email_ham_count=cv.transform(email_ham)
model.predict(email_ham_count)'''
# Out:
# 'email_ham=["hey wanna meet up for the game"]\nemail_ham_count=cv.transform(email_ham)\nmodel.predict(email_ham_count)'

# %%
'''email_spam=[" money click"]
email_spam_count=cv.transform(email_spam)
model.predict(email_spam_count)'''
# Out:
# 'email_spam=[" money click"]\nemail_spam_count=cv.transform(email_spam)\nmodel.predict(email_spam_count)'

# %%
'''x_test_count=cv.transform(x_test)
model.score(x_test_count,y_test)'''
# Out:
# 'x_test_count=cv.transform(x_test)\nmodel.score(x_test_count,y_test)'

# %%
def predict_spam(email):
    email_vectorized=cv.transform([email])
    prediction=model.predict(email_vectorized)
    return prediction[0]

# %%
while True:
    user_input=input(" \n Enter a new mail:")
    if user_input.lower()=='exit':
        break

    prediction=predict_spam(user_input)

    if prediction=='1':
        print("this email is classified as spam.")

    else:
        print(" \n This email is not spam")
# Out:
#
#  Enter a new mail: You received this message because you are subscribed to the Google Groups "Announcements group for CS courses" group. To unsubscribe from this group and stop receiving emails from it, send an email to cs-announce+unsubscribe@nptel.iitm.ac.in. To view this discussion visit https://groups.google.com/a/nptel.iitm.ac.in/d/msgid/cs-announce/CAFi4wK8tusHMza48b11TQZqkOtvF%3DHwTAzncBYA_ThoJ%2B5nSmQ%40mail.gmail.com. -- You received this message because you are subscribed to the Google Groups "Announcement list for Introduction To Machine Learning - IITKGP" group. To unsubscribe from this group and stop receiving emails from it, send an email to noc24-cs81-announce+unsubscribe@nptel.iitm.ac.in. To view this discussion visit https://groups.google.com/a/nptel.iitm.ac.in/d/msgid/noc24-cs81-announce/CAFi4wK8tusHMza48b11TQZqkOtvF%3DHwTAzncBYA_ThoJ%2B5nSmQ%40mail.gmail.com. For more options, visit https://groups.google.com/a/nptel.iitm.ac.in/d/optout.
#
# ...
