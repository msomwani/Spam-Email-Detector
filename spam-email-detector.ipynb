# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
spam_df = pd.read_csv(r"./spam.csv")
print(spam_df.head())
# Out:
#    label                                               text
# 0      1  ounce feather bowl hummingbird opec moment ala...
# 1      1  wulvob get your medircations online qnb ikud v...
# 2      0   computer connection from cnn com wednesday es...
# 3      1  university degree obtain a prosperous future m...
# 4      0  thanks for all your answers guys i know i shou...

# %%
spam_df.groupby('Category').describe()
# Out:
#         text
#        count unique                                                top freq
# label
# 0      39538  39538   computer connection from cnn com wednesday es...    1
# 1      43910  43910  ounce feather bowl hummingbird opec moment ala...    1

# %%
spam_df['spam']=spam_df['Category'].apply(lambda x:1 if x =='spam' else 0)

# %%
spam_df
# Out:
#        label                                               text  spam
# 0          1  ounce feather bowl hummingbird opec moment ala...     1
# 1          1  wulvob get your medircations online qnb ikud v...     1
# 2          0   computer connection from cnn com wednesday es...     0
# 3          1  university degree obtain a prosperous future m...     1
# 4          0  thanks for all your answers guys i know i shou...     0
# ...      ...                                                ...   ...
# 83443      0  hi given a date how do i get the last date of ...     0
# 83444      1  now you can order software on cd or download i...     1
# 83445      1  dear valued member canadianpharmacy provides a...     1
# 83446      0  subscribe change profile contact us long term ...     0
# 83447      1  get the most out of life ! viagra has helped m...     1
#
# [83448 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(spam_df.Message,spam_df.spam,test_size=0.25)

# %%
x_train
# Out:
# 60651    x @ nax , 150 x lmg tablets\nfind out about xa...
# 44667    author metze date escapenumber escapenumber es...
# 30677    alert name bush recruiting for school football...
# 75182    this is going to be our final notification\nwe...
# 81171    billows the fog cloaksi bring down a bit of it...
#                                ...
# 8373     nacional loterias sp\ncalle aberto 1 - 5 a\nma...
# 4309     hey guys ,\nyou may or may not be aware , but ...
# 56760    spoken tears letters pray remained somewhere f...
# 6769     while we may have high expectations of our ass...
# 34826    connecticut girl who vanished a year ago found...
# Name: text, Length: 62586, dtype: object

# %%
cv=CountVectorizer()
x_vectorized=cv.fit_transform(spam_df['Message'])

# %%
model=MultinomialNB()
model.fit(x_vectorized,spam_df['spam'])
# Out:
# MultinomialNB()

# %%
x_test_count=cv.transform(x_test)
model.score(x_test_count,y_test)
# Out:
# 0.9810181190681622

# %%
def predict_spam(email):
    email_vectorized=cv.transform([email])
    prediction=model.predict(email_vectorized)
    return prediction[0]

# %%
while True:
    user_input=input(" \n Enter a new mail:")
    if user_input.lower()=='exit':
        break

    prediction=predict_spam(user_input)

    if prediction=='1':
        print("this email is classified as spam.")

    else:
        print(" \n This email is not spam")
# Out:
#
#  Enter a new mail: PROJECT DESCRIPTION		BUDGET	 Grocery Mobile App with Web Admin   I'm seeking grocery mobile application ready made template, complete with a web-based admin panel constructed using either Python or Node.js. The app should operate off a pre-existing working template. Key Features: - ... See more Skills:  HTML | JavaScript | Node.js | Python | Website Design ₹1500 - ₹12500 INR Bid now AWS-Based Proxy Software Development   I'm in need of a skilled developer to create proxy software on AWS for me. The primary functionality of the software will be web traffic filtering. The software will need to integrate with my applications via an API. Ke ... See more Skills:  Amazon Web Services | Linux | Python | Software Architecture ₹75000 - ₹150000 INR Bid now Price File Maintenance Guru   I need an Excel Guru to manage our price file updates. Our pricefile contains approximately 13,000 items provided by approximately twenty different suppliers across Australia. The pricefile is used for manufacturing s ... See more Skills:  CAD/CAM | Data Entry | Data Mining | Data Processing | Excel ₹21499 - ₹64496 INR Bid now Virtual Executive Assistant for Start-Up   As a Virtual Executive Assistant, you will play a crucial role in supporting high-level business operations and ensuring seamless communication and task management. Your primary responsibility will be to maintain vigilan ... See more Skills:  Accounting | Data Entry | Documentation | Excel | Virtual Assistant ₹2580 - ₹21499 INR Bid now Advanced AI/ML Jewelry Management System   I'm seeking a professional who can create a sophisticated, web-based jewelry management system for me. This system should leverage advanced technologies, specifically AI and ML, to streamline operations and enhance custo ... See more Skills:  Graphic Design | Java | Machine Learning (ML) | MySQL | Website Design ₹1500 - ₹12500 INR Bid now Price File Maintenance Guru   I need an Excel Guru to manage our price file updates. Our pricefile contains approximately 13,000 items provided by approximately twenty different suppliers across Australia. The pricefile is used for manufacturing s ... See more Skills:  CAD/CAM | Data Entry | Data Mining | Data Processing | Excel ₹750 - ₹1250 INR /hr Bid now Vietnam-based Python Developers & Reach Developers for AI Project Only From Vietnam - ready to work for long term   I'm seeking a Vietnam-based Python developers& reach , Node Developers . The ideal candidate should have a strong command in DeepSeek or OpenAI, with good experience in vector search on Elasticsearch. I will share brie ... See more Skills:  Elasticsearch | Machine Learning (ML) | Node.js | Python | React.js ₹172 - ₹688 INR /hr Bid now All-Round Expert Needed for AI app   I'm in urgent need of a highly skilled professional with extensive experience in Az Open AI services, Az Function apps, Python, and mobile app development for my existing project. The scope of the job covers all aspects ... See more Skills:  iPhone | JavaScript | Mobile App Development | Python | Swift ₹1500 - ₹12500 INR Bid now Website Analysis & Data Entry for Banks (No Experience Needed)   I'm in need of a diligent, detail-oriented college fresher who can help me analyze the websites of 500-600 banks. The task involves researching and extracting relevant links into an Excel sheet. No prior experience is ne ... See more Skills:  Data Entry | Excel | Research | Web Search ₹1290 - ₹2150 INR /hr Bid now Medical Record Digitization into Excel   I have a set of images from a medical record book that need to be digitized into Excel. The records are organized by patient name and there are between 50 and 100 images, all in JPEG format. Key Requirements: - Create a ... See more Skills:  Copy Typing | Data Entry | Data Processing | Excel | Web Search ₹600 - ₹1500 INR Bid now Unity Developer (3D & C# Specialist) – 6-Month Fixed Contract -- 2     Sealed     We are looking for an experienced Unity Developer with expertise in 3D development a ...
#
#  This email is not spam
